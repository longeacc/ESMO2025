# %% [markdown]
# Pour lancer les fichiers .py il faut utiliser ce format de commmande pour ne pas avoir
# d'erreurs :
# Je suis actuellement dans le répertoire ~/ESMO2025>

# %% [markdown]
# Pour 2bis_train_hf_ner.py

# %% [markdown]
# cd "D:\CLEM\ESIEE SCHOOL\PARCOURS RECHERCHE\Le juste usage des LLM et méthode NLP en cancélorlogie\ESMO2025_Clement"; & ".venv/Scripts/python.exe" "ESMO2025/NER/src/2bis_train_hf_ner.py

# %% [markdown]
# Pour 4predict_to_brat.py :

# %% [markdown]
# & "D:/CLEM/ESIEE SCHOOL/PARCOURS RECHERCHE/Le juste usage des LLM et méthode NLP en cancélorlogie/ESMO2025_Clement/.venv/Scripts/python.exe" "d:/CLEM/ESIEE SCHOOL/PARCOURS RECHERCHE/Le juste usage des LLM et méthode NLP en cancélorlogie/ESMO2025_Clement/ESMO2025/NER/src/4predict_to_brat.py" --model_dir "models/sweeps/DrBERT-7GB_lr2e-05_bs16_ep10_wd0.01_wr0.1_frz2_sd42" --input_dir "Breast/CHIR/evaluation_set_breast_cancer_chir_GS" --out_dir "Breast/CHIR/evaluation_set_breast_cancer_chir_pred_ner"

# %% [markdown]
# Pour 1.convrte_brat_to_conll.py

# %% [markdown]
# cd "d:/CLEM/ESIEE SCHOOL/PARCOURS RECHERCHE/Le juste usage des LLM et méthode NLP en cancélorlogie/ESMO2025_Clement/ESMO2025" ; & "D:/CLEM/ESIEE SCHOOL/PARCOURS RECHERCHE/Le juste usage des LLM et méthode NLP en cancélorlogie/ESMO2025_Clement/.venv/Scripts/python.exe" "NER/src/1convert_brat_to_conll.py" --brat_dir "NER/data/raw/brat" --out_dir "NER/data/conll" --labels BIOMARKER STATUS VALUE METHOD --dev_ratio 0.2 --seed 42

# %% [markdown]
# Pour biomarker_brat_annotatorpy

# %% [markdown]
# & "D:\CLEM\ESIEE SCHOOL\PARCOURS RECHERCHE\Le juste usage des LLM et méthode NLP en cancélorlogie\ESMO2025_Clement\.venv\Scripts\python.exe" "d:\CLEM\ESIEE SCHOOL\PARCOURS RECHERCHE\Le juste usage des LLM et méthode NLP en cancélorlogie\ESMO2025_Clement\ESMO2025\Rules\src\biomarker_brat_annotator.py" "d:\CLEM\ESIEE SCHOOL\PARCOURS RECHERCHE\Le juste usage des LLM et méthode NLP en cancélorlogie\ESMO2025_Clement\ESMO2025\Rules\src\Breast\RCP\training_set_breast_cancer"

# %% [markdown]
# POur lunch.py

# %%
python lunch.py
